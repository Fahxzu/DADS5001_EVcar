# %%
#pip install youtube-comment-scraper-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 MB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for youtube-comment-scraper-python: filename=youtube_comment_scraper_python-1.0.0-py3-none-any.whl size=2496 sha256=864924459e1fe7ceaa1ee16364116f9c2f9de8665c271469ad2fa9cb81ae7c9a
#   Stored in directory: /root/.cache/pip/wheels/f8/c2/07/62c6de3fa077a37e888eeec058dd6a057eeaec518fd2d740f4
# ...
#   Created wheel for bot-studio: filename=bot_studio-1.4.0-py3-none-any.whl size=55391288 sha256=6b1e0900c3e87ccae3d7e8f9a48f27ab328c1bf1121f7214ca325bc0b3688c4f
#   Stored in directory: /root/.cache/pip/wheels/7a/37/f5/dc3c73c3113ad0b6e57fd17de17626ed61926d6131cd064d72
# Successfully built youtube-comment-scraper-python bot-studio
# ...

# %%
#import youtube_comment_scraper_python
#import requests
#import bot_studio
# Out:
# It currently works on windows only
# It currently works on windows only

# %%
#from youtube_comment_scraper_python import *
#import pandas as pd
#import time

#link = input("Youtube links: https://youtu.be/63Jp7rjw2cw")
#saved = input("Output name: ev car.csv")
#youtube.open(link)

#fullcomments = []
#for i in range(0, 10):
#  result = youtube.video_comments()
#  data = result['body']
#  fullcomments.extend(data)
#df = pd.DataFrame(fullcomments)
#df.to_csv(saved)
# Out:
# Youtube links: https://youtu.be/63Jp7rjw2cw
# Output name: ev car.csv
# It currently works on windows only
# It currently works on windows only
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7238f5a9c808> in <module>
#      10 for i in range(0, 10):
#      11   result = youtube.video_comments()
# ---> 12   data = result['body']
#      13   fullcomments.extend(data)
#      14 df = pd.DataFrame(fullcomments)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
pip install pytchat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 KB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 7.6 MB/s eta 0:00:00
# ...

# %%
import pytchat
import json

# %%
#import pytchat
#chat = pytchat.create(video_id = "Fncg9oH16O0")

#date = []
#while chat.is_alive():
  #for c in chat.get().sync_items():
    #date.append(c.datetime)

    #print(f"{c.datetime} [{c.author.name}] - {c.message}")
# Out:
# 2022-09-28 12:39:46 [Tanzineko] - น.. นั่นเขาใช่มั้ย พี่นพ extreme IT
# 2022-09-28 12:44:08 [Extreme IT] - สวัสดีคร๊าบ
# 2022-09-28 12:53:55 [beartai แบไต๋] - #แพนกันวันพุธ วันนี้คุยกับคุณนพ #ExtremeIT ในประเด็น พ.ศ. นี้ควรซื้อรถไฮบริดหรือรถไฟฟ้ากันแน่ ฝากกดไลก์ กดแชร์ ด้วยนะครับ
# 2022-09-28 12:58:15 [Atchariya Mana] - FC Extreme IT ค่าาา
# 2022-09-28 13:00:54 [Sarawut Tum] - สวัสดีครับ
# 2022-09-28 13:01:09 [Sarawut Tum] - ผมใหม่อะไรใหม่
# 2022-09-28 13:04:26 [Sritrung Sarawat] - นั่นสิ ซื้อรถอะไรดี
# 2022-09-28 13:09:03 [BeeR PP] - ถ้าคิดถึงเสียงเครื่อง BMW เขามี artificial sounds ยุนะครับ :grinning_squinting_face:
# 2022-09-28 13:09:11 [Pen Aek] - Infar. ทั้วประเทศพร้อมยังครับ
# 2022-09-28 13:11:02 [Pen Aek] - ตอนนี้ราคารถยนต์ Pure EV. ยังไม่เป็นมิตรกับเงินในกระเป๋าครับ :grinning_face_with_sweat::grinning_face_with_sweat::grinning_face_with_sweat:
# 2022-09-28 13:11:42 [Piglet] - อย่าซื้อรถยนต์ไฟฟ้า เดี๋ยวแย่งผมชาร์จไฟในช่วงเทศกาล
# ...

# %%
#f = open('Fncg9oH16O0.txt', 'w')
#chat = pytchat.create(video_id = 'Fncg9oH16O0')
#while chat.is_alive():
  #for c in chat.get().items:
    #obj = c.json()
    #print(obj)
    #obj2 = json.loads(obj)

   # f.write(str("{} : {}".format(obj2['author']['name'],obj2['message']).encode('utf8')))
   # f.write("\n")
    
#f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-104eb4688eaa> in <module>
#       6     #print(obj)
#       7     obj2 = json.loads(obj)
# ----> 8     print(obj2.info())
#       9    # f.write(str("{} : {}".format(obj2['author']['name'],obj2['message']).encode('utf8')))
#      10    # f.write("\n")
#
# AttributeError: 'dict' object has no attribute 'info'

# %%
import pytchat
chat = pytchat.create(video_id = "Fncg9oH16O0")

datelst = []
namelst = []
commentlst = []

while chat.is_alive():
  for c in chat.get().sync_items():
    print(f"{c.datetime} [{c.author.name}]- {c.message}")
    datelst.append(c.datetime)
    namelst.append(c.author.name)
    commentlst.append(c.message)
# Out:
# 2022-09-28 12:39:46 [Tanzineko]- น.. นั่นเขาใช่มั้ย พี่นพ extreme IT
# 2022-09-28 12:44:08 [Extreme IT]- สวัสดีคร๊าบ
# 2022-09-28 12:53:55 [beartai แบไต๋]- #แพนกันวันพุธ วันนี้คุยกับคุณนพ #ExtremeIT ในประเด็น พ.ศ. นี้ควรซื้อรถไฮบริดหรือรถไฟฟ้ากันแน่ ฝากกดไลก์ กดแชร์ ด้วยนะครับ
# 2022-09-28 12:58:15 [Atchariya Mana]- FC Extreme IT ค่าาา
# 2022-09-28 13:00:54 [Sarawut Tum]- สวัสดีครับ
# 2022-09-28 13:01:09 [Sarawut Tum]- ผมใหม่อะไรใหม่
# 2022-09-28 13:04:26 [Sritrung Sarawat]- นั่นสิ ซื้อรถอะไรดี
# 2022-09-28 13:09:03 [BeeR PP]- ถ้าคิดถึงเสียงเครื่อง BMW เขามี artificial sounds ยุนะครับ :grinning_squinting_face:
# 2022-09-28 13:09:11 [Pen Aek]- Infar. ทั้วประเทศพร้อมยังครับ
# 2022-09-28 13:11:02 [Pen Aek]- ตอนนี้ราคารถยนต์ Pure EV. ยังไม่เป็นมิตรกับเงินในกระเป๋าครับ :grinning_face_with_sweat::grinning_face_with_sweat::grinning_face_with_sweat:
# 2022-09-28 13:11:42 [Piglet]- อย่าซื้อรถยนต์ไฟฟ้า เดี๋ยวแย่งผมชาร์จไฟในช่วงเทศกาล
# ...

# %%
#dictionary of list
dict = {'DateTime': datelst, 'Username': namelst, 'Comment': commentlst}

# %%
import pandas as pd
df = pd.DataFrame(dict)
df.head()
# Out:
#               DateTime        Username  \
# 0  2022-09-28 12:39:46       Tanzineko
# 1  2022-09-28 12:44:08      Extreme IT
# 2  2022-09-28 12:53:55   beartai แบไต๋
# 3  2022-09-28 12:58:15  Atchariya Mana
# 4  2022-09-28 13:00:54     Sarawut Tum
#
#                                              Comment
# 0                น.. นั่นเขาใช่มั้ย พี่นพ extreme IT
# 1                                        สวัสดีคร๊าบ
# 2  #แพนกันวันพุธ วันนี้คุยกับคุณนพ #ExtremeIT ในป...
# 3                                FC Extreme IT ค่าาา
# 4                                         สวัสดีครับ

# %%
from google.colab import files
df.to_csv("data.csv", encoding="utf_8_sig", index=False) 
#cp874, 
#TIS-620
files.download("data.csv")
